# %%
# Week 1 - task 1
user_name = input("What is our name? ")
import random
random_number = random.randint(1,10)
#random_number = 7 #- this was to test correct answer, for value 7
user_number = int(input("Please guess what number between 1 and 10 I have in mind. "))
if user_number == random_number:
  print("Well done ",user_name, " you have guessed correctly.")
else: print("Sorry, not a right guess")

# %%
# Week 1 - Task 2
user_number = int(input("Hiya, I have 100 of great jokes to tell you, which one do you want to hear? Pick a number from 1 to 100...    "))
if user_number > 100:
 user_number = int(input("Remember, I only have 100 jokes, pick a different number from 1 to 100 "))
if user_number < 25:
  print("I stand corrected! said the man in the orthopedic shoes.")
elif 25 <= user_number < 50:
  print("I used to be addicted to soap. But I'm clean now.")
elif 50 <+ user_number < 75:
  print("Never criticize someone until you have walked a mile in their shoes. That way, when you criticize them, you'll be a mile away, and you'll have their shoes.")
elif 75 <= user_number <= 100:
  print("Though I enjoy the sport, I could never date a tennis player. Love means nothing to them.")
else: print("Remember, I only have 100 jokes, pick different number from 1 to 100")

# %%
# Week 1 - Task 3
starter = str(input("Let me guess what your favourite meal is, can you share what your favourite starter is? "))
main    = str(input("Thanks, what would you like most for a main course? "))
dessert = str(input("Fantastic, what's your favourite dessert?  "))
drink   = str(input("Amazing, and what would you like for a drink?  "))
print("Hey, Your favourite meal is a", starter, "with", main, "followed up with ", dessert, "for a dessert with a glass of", drink, ".")

# %%
# Week 1 - Task 4
bike_cost = 2000
depreciaton = 0.1
next_value = (bike_cost - bike_cost*0.1)
while (next_value > 1000):
  print(next_value)
  next_value = (next_value - next_value*0.1)
#print("stop")

# %%
# Week 1 - Task 5
number1 = float(input("Insert your first number for you calculation: "))
number2 = float(input("Insert 2nd number for your calculation: "))
#Operators = {"a":"+","b":"-","c":"*","d":"/","e":"**"}
Operation = input("Choose your operation: type one of the symbols: +, -, /, * or ^ for power of)")
#print(number1 Operation number2) # not sure how to put operator into formula from variable inputted by user
if Operation  == "+":
  print(number1,"+",number2,"=", number1 + number2)
elif Operation == "-":
  print(number1,"-",number2,"=", number1 - number2)
elif Operation == "*":
  print(number1,"*",number2,"=", number1 * number2)
elif Operation == "/":
  print(number1,"/",number2,"=", number1 / number2)
elif Operation == "^":
  print(number1,"to the power of",number2,"=", number1 ** number2)
else: print("try again")
